# %%
import pandas as pd
import numpy as np
import random

# %%
product = []
state = [] 
weekend = []
grade = []
organic = []
retention_per_store = []
distance_from_distributor = []
freshness = []
Seasonal = []
Otipy_certified_producer= []
unique_customers = []
price = []
demand = []

# %% [raw]
# Product => it states the product code of the harvest
#            product code       Product Name
#            1                  Potato
#            2                  Onion
#            3                  tomato
#            4                  Mango
#            5                  Banana
#
#
#
# weekend => a 0 or 1 value which tells if the crop is ordered on a weekend or not.
#            If the crop is ordered on a weekend it may lead to a small hike in price
#
#
# State => The state in which the product is produced.
#            State Code         State Name
#            1                  Haryana
#            2                  Punjab
#            3                  Andhra Pradesh
#            4                  Telangna
#
#
# Grade => A grade assigned to each crop after examining and testing it thoroughly
#          Grades=> 4  >  3  >  2  >  1
#
#
# Organic => A 0 or 1 value which tells if crop is organic or not
#            If the crop is organic its price and demand are likely to go higher than other crops
#
#
# Retention Per Store => A value which is calculated on the basis of customer retained on a regular basis for a specific
#                        product.
#                        If retention for the crop is high for a crop then the price and demand will rise.
#                        Retention per store will have a range from 0 to 1
#
#
# Distance from Distributor => A measure which indicates the Distance from Distributor
#                              Then the distance is high then the price will go up
#                              It will range from 0 to 1
#
#
# Freshness=> This feature measures the freshness of the crop i.e time taken from producer to distributor
#             Freshness is a feature which determines how much time is taken for the crop to reach from the field to customer
#             Its value is between 0 to 1
#
#
# Seasonal => a 0 or 1 value which tells if the crop is seasonal or not
#             A seasonal crop is expected to have a price lower than non seasonal one.
#
#
# Otipy_Certified => 0 or 1 value. A special feature which a producer is awarded after going through multiple checks and
#                    examination by otipy agricultural officers. "Otipy Ready"
#
#
# Unique customers => No of customers who bought the product
#
#
# Price => The price of the product on a specific scale
#
#
# Demand => No of products which are ordered for selling

# %%
def enter_values_1(list1,list2, list3, list4, list5, list6, list7, list8, list9, list10, list11, list12, list13, crop, high_grade, organic_val, high_retention, high_distance, high_freshness, otipy_verified, high_price, high_demand):
#9 , 12
#13, 14
#9,14
    
    
    if high_grade+high_demand+high_distance+high_freshness+high_price+high_retention <9:
        print("yes")

        grade_range = [3,4]
        retention_range = [0.7, 1]
        distance_range = [0.7, 1]
        organic_val = [1]
        freshness_range = [0.7, 1]
        if crop == 1:
            price_range = [25,30]
        if crop == 2:
            price_range = [50,60]
        if crop == 3:
            price_range = [50,60]
        if crop == 4:
            price_range = [150, 180]
        if crop == 5:
            price_range = [70, 90]
        customer_range = [8000, 15000]
        if crop == 1 or crop == 2 or crop==3:
            state_val = [1, 2]
        if crop == 4 or crop == 5:
            state_val = [3, 4]
    
    
    elif high_grade+high_demand+high_distance+high_freshness+high_price+high_retention>12 :
        print("no")
        grade_range = [1, 2]
        otipy_verified = 0
        retention_range = [0, 0.4]
        otipy_verified = 0
        distance_range = [0, 0.4]
        freshness_range = [0, 0.4]
        organic_val = [0]
        if crop == 1:
            price_range = [10, 17]
        if crop == 2:
            price_range = [20, 35]
        if crop == 3:
            price_range = [20, 35]
        if crop == 4:
            price_range = [70, 100]
        if crop == 5:
            price_range = [30, 50]
        customer_range = [1000, 5000]
        if crop == 1 or crop == 2 or crop==3:
            state_val = [3, 4]
        if crop == 4 or crop == 5:
            state_val = [1, 2]
    else:
        print("meh")
        if crop == 1:
            price_range = [15, 20]
        if crop == 2:
            price_range = [35, 50]
        if crop == 3:
            price_range = [35, 50]
        if crop == 4:
            price_range = [100, 150]
        if crop == 5:
            price_range = [50, 70]
        state_val=[1,4]
        grade_range=[2,3]
        freshness_range=[0.4, 0.7]
        distance_range = [0.4, 0.7]
        retention_range= [0.4, 0.7]
        organic_val = [0,1]
        customer_range = [5000,8000]
            
    seasonal_val = random.choice([0,1])        
    weekend_val = random.choice([0,1])
    otipy_verified = random.choice([0,1])
    list1.append(crop)
    list2.append(random.randint(state_val[0], state_val[1]))
    list3.append(weekend_val)
    list4.append(random.randint(grade_range[0], grade_range[1]))
    list5.append(random.choice(organic_val))
    list6.append(round(random.uniform(retention_range[0], retention_range[1]),3))
    list7.append(round(random.uniform(distance_range[0], distance_range[1]),3))
    list8.append(round(random.uniform(freshness_range[0], freshness_range[1]),3))
    list9.append(seasonal_val)
    list10.append(otipy_verified)
    if otipy_verified and organic_val and weekend_val and seasonal_val:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        no_of_customer = int(no_of_customer + no_of_customer*0.1)
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        price_crop = price_crop + price_crop*0.1
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(2000, 3000)
        list13.append(demand_val)
    elif otipy_verified or organic_val or weekend_val or seasonal_val:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        no_of_customer = int(no_of_customer + no_of_customer*0.05)
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        price_crop = price_crop + price_crop*0.05
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(1000, 2000)
        list13.append(demand_val)
    else:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(500, 1000)
        list13.append(demand_val)

# %%
def enter_values_2(list1,list2, list3, list4, list5, list6, list7, list8, list9, list10, list11, list12, list13, crop, high_grade, organic_val, high_retention, high_distance, high_freshness, otipy_verified, high_price, high_demand):
#9 , 12
#13, 14
#9,14
    
    
    if high_grade+high_demand+high_distance+high_freshness+high_price+high_retention <13:
        print("yes")

        grade_range = [3,4]
        retention_range = [0.7, 1]
        distance_range = [0.7, 1]
        organic_val = [1]
        freshness_range = [0.7, 1]
        if crop == 1:
            price_range = [25,30]
        if crop == 2:
            price_range = [50,60]
        if crop == 3:
            price_range = [50,60]
        if crop == 4:
            price_range = [150, 180]
        if crop == 5:
            price_range = [70, 90]
        customer_range = [8000, 15000]
        if crop == 1 or crop == 2 or crop==3:
            state_val = [1, 2]
        if crop == 4 or crop == 5:
            state_val = [3, 4]
    
    
    elif high_grade+high_demand+high_distance+high_freshness+high_price+high_retention>14 :
        print("no")
        grade_range = [1, 2]
        otipy_verified = 0
        retention_range = [0, 0.4]
        otipy_verified = 0
        distance_range = [0, 0.4]
        freshness_range = [0, 0.4]
        organic_val = [0]
        if crop == 1:
            price_range = [10, 17]
        if crop == 2:
            price_range = [20, 35]
        if crop == 3:
            price_range = [20, 35]
        if crop == 4:
            price_range = [70, 100]
        if crop == 5:
            price_range = [30, 50]
        customer_range = [1000, 5000]
        if crop == 1 or crop == 2 or crop==3:
            state_val = [3, 4]
        if crop == 4 or crop == 5:
            state_val = [1, 2]
    else:
        print("meh")
        if crop == 1:
            price_range = [15, 20]
        if crop == 2:
            price_range = [35, 50]
        if crop == 3:
            price_range = [35, 50]
        if crop == 4:
            price_range = [100, 150]
        if crop == 5:
            price_range = [50, 70]
        state_val=[1,4]
        grade_range=[2,3]
        freshness_range=[0.4, 0.7]
        distance_range = [0.4, 0.7]
        retention_range= [0.4, 0.7]
        organic_val = [0,1]
        customer_range = [5000,8000]
            
    seasonal_val = random.choice([0,1])        
    weekend_val = random.choice([0,1])
    otipy_verified = random.choice([0,1])
    list1.append(crop)
    list2.append(random.randint(state_val[0], state_val[1]))
    list3.append(weekend_val)
    list4.append(random.randint(grade_range[0], grade_range[1]))
    list5.append(random.choice(organic_val))
    list6.append(round(random.uniform(retention_range[0], retention_range[1]),3))
    list7.append(round(random.uniform(distance_range[0], distance_range[1]),3))
    list8.append(round(random.uniform(freshness_range[0], freshness_range[1]),3))
    list9.append(seasonal_val)
    list10.append(otipy_verified)
    if otipy_verified and organic_val and weekend_val and seasonal_val:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        no_of_customer = int(no_of_customer + no_of_customer*0.1)
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        price_crop = price_crop + price_crop*0.1
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(2000, 3000)
        list13.append(demand_val)
    elif otipy_verified or organic_val or weekend_val or seasonal_val:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        no_of_customer = int(no_of_customer + no_of_customer*0.05)
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        price_crop = price_crop + price_crop*0.05
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(1000, 2000)
        list13.append(demand_val)
    else:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(500, 1000)
        list13.append(demand_val)

# %%
def enter_values_3(list1,list2, list3, list4, list5, list6, list7, list8, list9, list10, list11, list12, list13, crop, high_grade, organic_val, high_retention, high_distance, high_freshness, otipy_verified, high_price, high_demand):
#9 , 12
#13, 14
#9,14
    
    
    if high_grade+high_demand+high_distance+high_freshness+high_price+high_retention <9:
        print("yes")

        grade_range = [3,4]
        retention_range = [0.7, 1]
        distance_range = [0.7, 1]
        organic_val = [1]
        freshness_range = [0.7, 1]
        if crop == 1:
            price_range = [25,30]
        if crop == 2:
            price_range = [50,60]
        if crop == 3:
            price_range = [50,60]
        if crop == 4:
            price_range = [150, 180]
        if crop == 5:
            price_range = [70, 90]
        customer_range = [8000, 15000]
        if crop == 1 or crop == 2 or crop==3:
            state_val = [1, 2]
        if crop == 4 or crop == 5:
            state_val = [3, 4]
    
    
    elif high_grade+high_demand+high_distance+high_freshness+high_price+high_retention>14 :
        print("no")
        grade_range = [1, 2]
        otipy_verified = 0
        retention_range = [0, 0.4]
        otipy_verified = 0
        distance_range = [0, 0.4]
        freshness_range = [0, 0.4]
        organic_val = [0]
        if crop == 1:
            price_range = [10, 17]
        if crop == 2:
            price_range = [20, 35]
        if crop == 3:
            price_range = [20, 35]
        if crop == 4:
            price_range = [70, 100]
        if crop == 5:
            price_range = [30, 50]
        customer_range = [1000, 5000]
        if crop == 1 or crop == 2 or crop==3:
            state_val = [3, 4]
        if crop == 4 or crop == 5:
            state_val = [1, 2]
    else:
        print("meh")
        if crop == 1:
            price_range = [15, 20]
        if crop == 2:
            price_range = [35, 50]
        if crop == 3:
            price_range = [35, 50]
        if crop == 4:
            price_range = [100, 150]
        if crop == 5:
            price_range = [50, 70]
        state_val=[1,4]
        grade_range=[2,3]
        freshness_range=[0.4, 0.7]
        distance_range = [0.4, 0.7]
        retention_range= [0.4, 0.7]
        organic_val = [0,1]
        customer_range = [5000,8000]
            
    seasonal_val = random.choice([0,1])        
    weekend_val = random.choice([0,1])
    otipy_verified = random.choice([0,1])
    list1.append(crop)
    list2.append(random.randint(state_val[0], state_val[1]))
    list3.append(weekend_val)
    list4.append(random.randint(grade_range[0], grade_range[1]))
    list5.append(random.choice(organic_val))
    list6.append(round(random.uniform(retention_range[0], retention_range[1]),3))
    list7.append(round(random.uniform(distance_range[0], distance_range[1]),3))
    list8.append(round(random.uniform(freshness_range[0], freshness_range[1]),3))
    list9.append(seasonal_val)
    list10.append(otipy_verified)
    if otipy_verified and organic_val and weekend_val and seasonal_val:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        no_of_customer = int(no_of_customer + no_of_customer*0.1)
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        price_crop = price_crop + price_crop*0.1
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(2000, 3000)
        list13.append(demand_val)
    elif otipy_verified or organic_val or weekend_val or seasonal_val:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        no_of_customer = int(no_of_customer + no_of_customer*0.05)
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        price_crop = price_crop + price_crop*0.05
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(1000, 2000)
        list13.append(demand_val)
    else:
        no_of_customer = random.randint(customer_range[0], customer_range[1])
        list11.append(no_of_customer)
        price_crop = random.randint(price_range[0], price_range[1])
        list12.append(price_crop)
        demand_val = no_of_customer + random.randint(500, 1000)
        list13.append(demand_val)

# %%
for i in range(1000):
    enter_values_1(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 1, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
    enter_values_2(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 1, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
    enter_values_3(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 1, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
for i in range(1000):
    enter_values_1(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 2, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
    enter_values_2(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 2, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
    enter_values_3(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 2, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
for i in range(1000):
    enter_values_1(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 3, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
    enter_values_2(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 3, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
    enter_values_3(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 3, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
for i in range(1000):
    enter_values_1(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 4, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
    enter_values_2(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 4, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
    enter_values_3(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand, crop = 4, high_grade = random.randint(1,3), organic_val=random.randint(0,1), high_retention=random.randint(1,3), high_distance=random.randint(1,3), high_freshness= random.randint(1,3), otipy_verified=random.randint(0,1), high_price = random.randint(1,3), high_demand=random.randint(1,3) )
# Out:
# meh
# yes
# meh
# meh
# yes
# meh
# meh
# yes
# meh
# meh
# yes
# meh
# meh
# no
# meh
# meh
# yes
# meh
# meh
# no
# meh
# no
# meh
# meh
# meh
# yes
# no
# no
# yes
# meh
# no
# yes
# no
# no
# yes
# meh
# meh
# meh
# meh
# no
# meh
# meh
# meh
# no
# meh
# meh
# no
# meh
# meh
# meh
# no
# meh
# yes
# meh
# no
# yes
# meh
# meh
# no
# meh
# meh
# no
# meh
# meh
# yes
# meh
# no
# meh
# meh
# meh
# yes
# meh
# no
# yes
# no
# no
# yes
# meh
# meh
# yes
# meh
# meh
# meh
# meh
# meh
# meh
# meh
# no
# yes
# meh
# yes
# no
# meh
# no
# meh
# meh
# no
# yes
# meh
# no
# meh
# meh
# no
# yes
# yes
# meh
# meh
# meh
# no
# yes
# meh
# meh
# yes
# meh
# no
# yes
# meh
# meh
# yes
# meh
# no
# yes
# meh
# meh
# meh
# meh
# yes
# yes
# meh
# meh
# yes
# meh
# meh
# yes
# meh
# no
# yes
# yes
# meh
# yes
# meh
# yes
# yes
# meh
# no
# yes
# no
# meh
# meh
# meh
# meh
# yes
# meh
# meh
# yes
# no
# no
# yes
# meh
# yes
# yes
# meh
# meh
# yes
# meh
# meh
# yes
# meh
# no
# yes
# meh
# meh
# ...

# %%
len(state)
# Out:
# 12000

# %%
df = pd.DataFrame(list(zip(product, state, weekend, grade, organic, retention_per_store, distance_from_distributor, freshness, Seasonal, Otipy_certified_producer, unique_customers, price, demand)), columns=['Item', 'State', 'Weekend', 'Grade', "Organic", "RPS", "DFD", "Freshness", 'Seasonal', "Otipy_certified", 'Unique_Customors', "Price", "Demand"])

# %%
df
# Out:
#        Item  State  Weekend  Grade  Organic    RPS    DFD  Freshness  \
# 0         1      1        0      2        1  0.678  0.467      0.513
# 1         1      2        0      4        1  0.767  0.965      0.905
# 2         1      4        1      2        1  0.403  0.654      0.486
# 3         1      2        0      3        0  0.678  0.493      0.602
# 4         1      1        1      3        1  0.764  0.885      0.804
# ...     ...    ...      ...    ...      ...    ...    ...        ...
# 11995     4      3        1      3        1  0.856  0.898      0.840
# 11996     4      3        1      3        0  0.542  0.506      0.432
# 11997     4      3        0      3        0  0.581  0.604      0.655
# 11998     4      3        1      4        1  0.863  0.847      0.878
# 11999     4      3        0      2        1  0.660  0.637      0.662
#
#        Seasonal  Otipy_certified  Unique_Customors   Price  Demand
# 0             0                0              6606   15.75    8365
# ...

# %%
df.to_csv("AgriTech_Dataset.csv")
